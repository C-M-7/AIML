# %%
import numpy as np
import pandas as pd

# %%
train_data = pd.read_csv("train.csv")
print(train_data.shape)
train_data
# Out:
# (379, 14)
#        # CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.407850 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
# 1   -0.407374 -0.487722  0.247057 -0.272599 -1.016689  0.001946 -0.838337
# 2    0.125179 -0.487722  1.015999 -0.272599  1.367490 -0.439699  0.687212
# 3    0.028304 -0.487722  1.015999 -0.272599  1.859875 -0.047918  0.801005
# 4   -0.412408 -0.487722 -0.969827 -0.272599 -0.913029 -0.384137 -0.834781
# ..        ...       ...       ...       ...       ...       ...       ...
# 374 -0.204929 -0.487722  1.231945  3.668398  0.434551  2.161728  1.053485
# 375  0.231398 -0.487722  1.015999 -0.272599  1.367490  0.215644  0.687212
# 376 -0.408311 -0.487722  0.247057 -0.272599 -1.016689 -0.206055 -0.809889
# 377 -0.410620 -0.487722 -1.152214 -0.272599 -0.818007  0.068904 -1.826921
# 378  0.342909 -0.487722  1.015999  3.668398  0.659147  1.041946  1.028593
#
# ...

# %%
# in Pandas we have to use .iloc for retrieving any specific row or col from dataset
x_train = train_data.iloc[:,0:13]
x_train
# Out:
#        # CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.407850 -0.487722 -1.266023 -0.272599 -0.576134  1.239974  0.840122
# 1   -0.407374 -0.487722  0.247057 -0.272599 -1.016689  0.001946 -0.838337
# 2    0.125179 -0.487722  1.015999 -0.272599  1.367490 -0.439699  0.687212
# 3    0.028304 -0.487722  1.015999 -0.272599  1.859875 -0.047918  0.801005
# 4   -0.412408 -0.487722 -0.969827 -0.272599 -0.913029 -0.384137 -0.834781
# ..        ...       ...       ...       ...       ...       ...       ...
# 374 -0.204929 -0.487722  1.231945  3.668398  0.434551  2.161728  1.053485
# 375  0.231398 -0.487722  1.015999 -0.272599  1.367490  0.215644  0.687212
# 376 -0.408311 -0.487722  0.247057 -0.272599 -1.016689 -0.206055 -0.809889
# 377 -0.410620 -0.487722 -1.152214 -0.272599 -0.818007  0.068904 -1.826921
# 378  0.342909 -0.487722  1.015999  3.668398  0.659147  1.041946  1.028593
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT
# ...

# %%
y_train = train_data.iloc[:,13]
y_train
# Out:
# 0      37.9
# 1      21.4
# 2      12.7
# 3      19.9
# 4      22.5
#        ...
# 374    50.0
# 375    14.3
# 376    20.8
# 377    22.6
# 378    50.0
# Name:  Y, Length: 379, dtype: float64

# %% [markdown]
# # As we have retrieved the train data in x and y terms so now we can implement our model

# %%
from sklearn.ensemble import GradientBoostingRegressor
model = GradientBoostingRegressor()
# Getting the inbuilt function of GD

# %%
model.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %% [markdown]
# # Now getting the test data

# %%
x_test = np.loadtxt("test.csv",delimiter=",")
print(x_test.shape)
x_test
# Out:
# (127, 13)
# array([[ 2.91816626, -0.48772236,  1.01599907, ...,  0.80657583,
#         -1.59755122,  1.04106182],
#        [-0.40339151, -0.48772236,  0.40609801, ..., -1.13534664,
#          0.44105193, -0.89473812],
#        [-0.4131781 , -0.48772236,  0.11573841, ...,  1.17646583,
#          0.44105193, -0.50084979],
#        ...,
#        [-0.41001449,  2.08745172, -1.37837329, ..., -0.0719129 ,
#          0.39094481, -0.68167397],
#        [-0.40317611, -0.48772236, -0.37597609, ...,  1.13022958,
#          0.34007019,  0.20142086],
#        [-0.13356344, -0.48772236,  1.2319449 , ..., -1.73641788,
#         -2.93893082,  0.48877712]])

# %%
y_predict = model.predict(x_test)
y_predict
# Out:
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GradientBoostingRegressor was fitted with feature names
#   warnings.warn(
# array([11.89733008, 26.80499145, 17.09852907, 22.06512279, 21.19058003,
#        12.2832724 , 28.87118865, 25.20237061, 18.77275134, 22.99272373,
#        23.39058111, 17.6291958 , 19.64676654, 20.87639405, 51.86380438,
#        20.4503074 , 23.49131107, 22.87310447, 19.17816831, 30.6365982 ,
#        20.89789526, 21.49588187, 36.62299579, 31.39775722, 33.27921713,
#        16.38574194, 20.47642029, 30.64770333, 19.97381035, 28.7847961 ,
#        17.218498  , 24.68879147, 20.79190642, 22.83448526,  8.58056865,
#        23.80896034, 22.57697789, 20.44057093, 22.71189925,  8.0482711 ,
#        15.21709928, 23.59244202, 24.78663662, 19.90148152, 21.80376912,
#         9.59983155, 43.705159  , 24.57774682, 34.28758074, 12.83411894,
# ...

# %%
np.savetxt("y_predict.csv", y_predict)
